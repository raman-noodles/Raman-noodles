# %% [markdown]
# ## Use shoyu.py

# %%
import shoyu
import pickle

# %% [markdown]
# Use this notebook to add new compounds to the shoyu_data_dict.
# Handles CAS numbers with or without dashes.
# `label=None` takes label from the title of the jdx.

# %%
shoyu_data_dict = shoyu.more_please('50-00-0', label=None)
# Out:
# file downloaded too raman_spectra folder
# FORMALDEHYDE added to shoyu_data_dict.p

# %%
sorted(shoyu_data_dict.keys())
# Out:
# ['2-PROPANOL',
#  'Benzene',
#  'CARBON DIOXIDE',
#  'CARBON MONOXIDE',
#  'DIMETHYL KETONE',
#  'ETHANE',
#  'ETHYL ALCOHOL',
#  'FORMIC ACID',
#  'METHANE',
#  'WATER',
#  'n-PENTANE']

# %% [markdown]
# Use the two commands below to delete an entry from shoyu_data_dict.p
# Be sure to pickle dump or the entry will still be there next time a spectra is added.

# %%
# Out:
# {'CARBON MONOXIDE': {'title': 'CARBON MONOXIDE',
#   'jcamp-dx': 4.24,
#   'data type': 'INFRARED SPECTRUM',
#   'class': 'COBLENTZ',
#   'origin': 'DOW CHEMICAL COMPANY',
#   'owner': 'COBLENTZ SOCIETY',
#   'date': 1964,
#   'cas registry no': '630-08-0',
#   'molform': 'C O',
#   'source reference': 'COBLENTZ NO. 8755',
#   '$nist source': 'COBLENTZ',
#   '$nist image': 'cob8755',
#   'spectrometer/data system': 'DOW KBr FOREPRISM',
#   'instrument parameters': 'GRATING CHANGED AT 5.0, 7.5, 15.0 MICRON',
#   'state': 'GAS (400 mmHg DILUTED TO A TOTAL PRESSURE OF 600 mmHg WITH N2)',
#   'path length': '10 CM',
#   'sampling procedure': 'TRANSMISSION',
#   'resolution': 4,
#   'data processing': 'DIGITIZED BY NIST FROM HARD COPY (FROM TWO SEGMENTS)',
#   'xunits': '1/CM',
#   'yunits': 'ABSORBANCE',
#   'xfactor': 1.0,
#   'yfactor': 1,
#   'deltax': 0.936332,
#   'firstx': 457.865,
#   'lastx': 3803.38,
#   'firsty': 0.961,
#   'maxx': 3803.38,
#   'minx': 457.865,
#   'maxy': 1.021,
#   'miny': 0.14603,
#   'npoints': 3574,
#   'xydata': '(X++(Y..Y))',
#   'end': '',
#   'x': array([ 457.865     ,  459.03541525,  460.2058305 , ..., 3801.50752733,
#          3802.44376367, 3803.38      ]),
#   'y': array([0.039, 0.039, 0.039, ..., 0.005, 0.005, 0.005]),
#   'filename': 'raman_spectra/630080_NIST_IR.jdx'},
#  'CARBON DIOXIDE': {'title': 'CARBON DIOXIDE',
#   'jcamp-dx': 4.24,
#   'data type': 'INFRARED SPECTRUM',
#   'class': 'COBLENTZ',
#   'origin': 'DOW CHEMICAL COMPANY',
#   'owner': 'COBLENTZ SOCIETY',
#   'date': 1964,
#   'names': 'dioxomethane',
#   'cas registry no': '124-38-9',
#   'molform': 'C O2',
#   'source reference': 'COBLENTZ NO. 8753',
#   '$nist source': 'COBLENTZ',
#   '$nist image': 'cob8753',
#   'spectrometer/data system': 'DOW KBr FOREPRISM',
#   'instrument parameters': 'GRATING CHANGED AT 5.0, 7.5, 15.0 MICRON',
#   'state': 'GAS (200 mmHg DILUTED TO A TOTAL PRESSURE OF 600 mmHg WITH N2)',
#   'path length': '10 CM',
#   'sampling procedure': 'TRANSMISSION',
#   'resolution': 4,
#   'data processing': 'DIGITIZED BY NIST FROM HARD COPY (FROM TWO SEGMENTS)',
#   'xunits': '1/CM',
#   'yunits': 'ABSORBANCE',
#   'xfactor': 1.0,
#   'yfactor': 1,
#   'deltax': 0.934582,
#   'firstx': 458.879,
#   'lastx': 3797.21,
#   'firsty': 0.973,
#   'maxx': 3797.21,
#   'minx': 458.879,
#   'maxy': 1.023,
#   'miny': 0.018,
#   'npoints': 3573,
#   'xydata': '(X++(Y..Y))',
#   'end': '',
#   'x': array([ 458.879    ,  460.047228 ,  461.215456 , ..., 3795.338041 ,
#          3796.2740205, 3797.21     ]),
#   'y': array([ 0.027 ,  0.027 ,  0.028 , ..., -0.001 , -0.0009,  0.0026]),
#   'filename': 'raman_spectra/124389_NIST_IR.jdx'},
#  'WATER': {'title': 'WATER',
#   'jcamp-dx': 4.24,
#   'data type': 'INFRARED SPECTRUM',
#   'class': 'COBLENTZ III',
#   'origin': 'DOW CHEMICAL COMPANY',
#   'owner': 'COBLENTZ SOCIETY',
#   'date': '1969/10/21',
#   'cas registry no': '7732-18-5',
#   'molform': 'H2 O',
#   'source reference': 'COBLENTZ NO. 10116',
#   '$nist source': 'COBLENTZ',
#   '$nist image': 'cob10116',
#   'spectrometer/data system': 'DOW KBr FOREPRISM-GRATING',
#   'instrument parameters': 'BLAZED AT 3.5, 12.0, 20.0 MICRON, CHANGED AT 5.0, 7.5, 14.9 MICRON',
#   'state': 'LIQUID (NEAT)',
#   'path length': 'CAPILLARY, AgCl PLATES',
#   'sampling procedure': 'TRANSMISSION',
#   'resolution': 4,
#   'data processing': 'DIGITIZED BY NIST FROM HARD COPY (FROM TWO SEGMENTS)',
#   'xunits': '1/CM',
#   'yunits': 'ABSORBANCE',
#   'xfactor': 1.0,
#   'yfactor': 1,
#   'deltax': 0.870985,
#   'firstx': 388.677,
#   'lastx': 3799.46,
#   'firsty': 0.438,
#   'maxx': 3799.46,
#   'minx': 388.677,
#   'maxy': 0.987,
#   'miny': 0.001,
#   'npoints': 3917,
#   'xydata': '(X++(Y..Y))',
#   'end': '',
#   'x': array([ 388.677     ,  389.76573175,  390.8544635 , ..., 3798.584862  ,
#          3798.584862  , 3799.46      ]),
#   'y': array([0.562 , 0.562 , 0.563 , ..., 0.1147, 0.115 , 0.115 ]),
#   'filename': 'raman_spectra/7732185_NIST_IR.jdx'},
#  'FORMIC ACID': {'title': 'FORMIC ACID',
#   'jcamp-dx': 4.24,
#   'data type': 'INFRARED SPECTRUM',
#   'class': 'COBLENTZ',
#   'origin': 'DOW CHEMICAL COMPANY',
#   'owner': 'COBLENTZ SOCIETY',
#   'date': 1964,
#   'cas registry no': '64-18-6',
#   'molform': 'C H2 O2',
#   'source reference': 'COBLENTZ NO. 8778',
#   '$nist source': 'COBLENTZ',
#   '$nist image': 'cob-r8778',
#   'spectrometer/data system': 'DOW KBr FOREPRISM-GRATING',
#   'instrument parameters': 'GRATING CHANGED AT 5.0, 7.5, 14.9 MICRON',
#   'state': 'GAS (20 mmHg, N2 ADDED, TOTAL PRESSURE 600 mmHg)',
#   'path length': '5 CM',
#   'sampling procedure': 'TRANSMISSION',
#   'resolution': 2,
#   'data processing': 'DIGITIZED BY NIST FROM HARD COPY (FROM TWO SEGMENTS)',
#   'xunits': '1/CM',
#   'yunits': 'ABSORBANCE',
#   'xfactor': 1.0,
#   'yfactor': 1,
#   'deltax': 1.345298,
#   'firstx': 456.951,
#   'lastx': 3766.39,
#   'firsty': 0.915,
#   'maxx': 3766.39,
#   'minx': 456.951,
#   'maxy': 1.00665,
#   'miny': 0,
#   'npoints': 2461,
#   'xydata': '(X++(Y..Y))',
#   'end': '',
#   'x': array([ 456.951   ,  458.632623,  460.314246, ..., 3764.703426,
#          3766.385049, 3766.385049]),
#   'y': array([ 0.085 ,  0.085 ,  0.085 , ..., -0.002 , -0.0036, -0.0067]),
#   'filename': 'raman_spectra/64186_NIST_IR.jdx'},
#  'Benzene': {'title': 'Benzene',
#   'jcamp-dx': 4.24,
#   'data type': 'INFRARED SPECTRUM',
#   'class': 'COBLENTZ',
#   'origin': 'DOW CHEMICAL COMPANY',
#   'owner': 'Copyright (C) 1987 by the Coblentz Society',
#   'date': 1964,
#   'cas registry no': '71-43-2',
#   'molform': 'C6 H6',
#   'source reference': 'COBLENTZ NO. 8861',
#   '$nist source': 'COBLENTZ',
#   '$nist image': 'cob8861',
#   'spectrometer/data system': 'DOW KBr FOREPRISM-GRATING',
#   'instrument parameters': 'GRATING CHANGED AT 5.0, 7.5, 15.0 MICRON',
#   'state': 'GAS (70 mmHg, N2 ADDED, TOTAL PRESSURE 600 mmHg)',
#   'path length': '5 CM',
#   'sampling procedure': 'TRANSMISSION',
#   'resolution': 2,
#   'data processing': 'DIGITIZED BY COBLENTZ SOCIETY (BATCH II) FROM HARD COPY',
#   'xunits': '1/CM',
#   'yunits': 'ABSORBANCE',
#   'xfactor': 1.0,
#   'yfactor': 1,
#   'firstx': 452,
#   'lastx': 3794,
#   'firsty': 0.8787,
#   'maxx': 3794,
#   'minx': 452,
#   'maxy': 0.8868,
#   'miny': 0,
#   'npoints': 3343,
#   'xydata': '(X++(Y..Y))',
#   'end': '',
#   'x': array([ 452.  ,  453.25,  454.5 , ..., 3792.  , 3793.  , 3794.  ]),
#   'y': array([0.1213, 0.1213, 0.1213, ..., 0.1316, 0.1316, 0.1316]),
#   'filename': 'raman_spectra/71432_NIST_IR.jdx'},
#  'n-PENTANE': {'title': 'n-PENTANE',
#   'jcamp-dx': 4.24,
#   'data type': 'INFRARED SPECTRUM',
#   'class': 'COBLENTZ',
#   'origin': 'DOW CHEMICAL COMPANY',
#   'owner': 'COBLENTZ SOCIETY',
#   'date': '1976/02/11',
#   'names': 'pentane',
#   'cas registry no': '109-66-0',
#   'molform': 'C5 H12',
#   'source reference': 'COBLENTZ NO. 10475',
#   '$nist source': 'COBLENTZ',
#   '$nist image': 'cob10475',
#   'spectrometer/data system': 'PERKIN-ELMER 180',
#   'instrument parameters': 'I0 MODE RESOLUTION: 1 CM^-^1 AT 4000 CM^-^1',
#   'state': 'GAS (6 mmHg DILUTED TO A TOTAL PRESSURE OF 600 mmHg WITH N2)',
#   'path length': '18 CM CELL',
#   'sampling procedure': 'TRANSMISSION',
#   'resolution': 4,
#   'data processing': 'DIGITIZED BY NIST FROM HARD COPY (FROM TWO SEGMENTS)',
#   'xunits': '1/CM',
#   'yunits': 'ABSORBANCE',
#   'xfactor': 1.0,
#   'yfactor': 1,
#   'deltax': 1.042444,
#   'firstx': 400.894,
#   'lastx': 3998.37,
#   'firsty': 0.573,
#   'maxx': 3998.37,
#   'minx': 400.894,
#   'maxy': 0.86,
#   'miny': 0.046,
#   'npoints': 3452,
#   'xydata': '(X++(Y..Y))',
#   'end': '',
#   'x': array([ 400.894    ,  402.1970545,  403.500109 , ..., 3997.324435 ,
#          3997.324435 , 3998.37     ]),
#   'y': array([0.427, 0.422, 0.421, ..., 0.198, 0.198, 0.198]),
#   'filename': 'raman_spectra/109660_NIST_IR.jdx'},
#  'ETHANE': {'title': 'ETHANE',
#   'jcamp-dx': 4.24,
#   'data type': 'INFRARED SPECTRUM',
#   'class': 'COBLENTZ',
#   'origin': 'DOW CHEMICAL COMPANY',
#   'owner': 'COBLENTZ SOCIETY',
#   'date': 1964,
#   'cas registry no': '74-84-0',
#   'molform': 'C2 H6',
#   'source reference': 'COBLENTZ NO. 8868',
#   '$nist source': 'COBLENTZ',
#   '$nist image': 'cob8868',
#   'spectrometer/data system': 'DOW KBr FOREPRISM',
#   'instrument parameters': 'GRATING CHANGED AT 5.0, 7.5, 15.0 MICRON',
#   'state': 'GAS (150 mmHg DILUTED TO A TOTAL PRESSURE OF 600 mmHg WITH N2)',
#   'path length': '5 CM',
#   'sampling procedure': 'TRANSMISSION',
#   'resolution': 4,
#   'data processing': 'DIGITIZED BY NIST FROM HARD COPY (FROM TWO SEGMENTS)',
#   'xunits': '1/CM',
#   'yunits': 'ABSORBANCE',
#   'xfactor': 1.0,
#   'yfactor': 1,
#   'deltax': 0.939261,
#   'firstx': 450.219,
#   'lastx': 3803.38,
#   'firsty': 1.024,
#   'maxx': 3803.38,
#   'minx': 450.219,
#   'maxy': 1.10198,
#   'miny': 0.017,
#   'npoints': 3571,
#   'xydata': '(X++(Y..Y))',
#   'end': '',
#   'x': array([ 450.219    ,  451.3930765,  452.567153 , ..., 3802.2074505,
#          3803.381527 , 3803.381527 ]),
#   'y': array([-0.024 , -0.024 , -0.024 , ...,  0.0366,  0.037 ,  0.037 ]),
#   'filename': 'raman_spectra/74840_NIST_IR.jdx'},
#  'ETHYL ALCOHOL': {'title': 'ETHYL ALCOHOL',
#   'jcamp-dx': 4.24,
#   'data type': 'INFRARED SPECTRUM',
#   'class': 'COBLENTZ',
#   'owner': 'COBLENTZ SOCIETY',
#   'date': '1963/02/18',
#   'names': 'ETHANOL',
#   'cas registry no': '64-17-5',
#   'molform': 'C2 H6 O',
#   'source reference': 'COBLENTZ NO. 6986',
#   '$nist source': 'COBLENTZ',
#   '$nist image': 'cob6986',
#   'spectrometer/data system': 'PERKIN-ELMER 21 (GRATING)',
#   'state': 'GAS (VAPOR)',
#   'path length': '10 CM',
#   'sampling procedure': 'TRANSMISSION',
#   'resolution': 4,
#   'data processing': 'DIGITIZED BY NIST FROM HARD COPY',
#   'xunits': 'MICROMETERS',
#   'yunits': 'ABSORBANCE',
#   'xfactor': 1.0,
#   'yfactor': 1,
#   'deltax': 0.004756,
#   'firstx': 2.02,
#   'lastx': 15.0145,
#   'firsty': 0.753,
#   'maxx': 15.0145,
#   'minx': 2.02,
#   'maxy': 0.842,
#   'miny': 0.094,
#   'npoints': 2733,
#   'xydata': '(X++(Y..Y))',
#   'end': '',
#   'x': array([ 2.02     ,  2.0259475,  2.031895 , ..., 15.005    , 15.00975  ,
#          15.0145   ]),
#   'y': array([0.247, 0.247, 0.247, ..., 0.285, 0.285, 0.286]),
#   'filename': 'raman_spectra/64175_NIST_IR.jdx'},
#  'DIMETHYL KETONE': {'title': 'DIMETHYL KETONE',
#   'jcamp-dx': 4.24,
#   'data type': 'INFRARED SPECTRUM',
#   'class': 'COBLENTZ',
#   'owner': 'COBLENTZ SOCIETY',
#   'date': '1963/02/21',
#   'names': 'ACETONE',
#   'cas registry no': '67-64-1',
#   'molform': 'C3 H6 O',
#   'source reference': 'COBLENTZ NO. 7000',
#   '$nist source': 'COBLENTZ',
#   '$nist image': 'cob7000',
#   'spectrometer/data system': 'PERKIN-ELMER 21 (GRATING)',
#   'state': 'GAS (VAPOR)',
#   'path length': '10 CM',
#   'sampling procedure': 'TRANSMISSION',
#   'resolution': 4,
#   'data processing': 'DIGITIZED BY NIST FROM HARD COPY',
#   'xunits': 'MICROMETERS',
#   'yunits': 'ABSORBANCE',
#   'xfactor': 1.0,
#   'yfactor': 1,
#   'deltax': 0.004747,
#   'firstx': 2.003,
#   'lastx': 15,
#   'firsty': 0.793,
#   'maxx': 15,
#   'minx': 2.003,
#   'maxy': 0.854,
#   'miny': 0.03,
#   'npoints': 2739,
#   'xydata': '(X++(Y..Y))',
#   'end': '',
#   'x': array([ 2.003     ,  2.00893575,  2.0148715 , ..., 14.99049533,
#          14.99524767, 15.        ]),
#   'y': array([0.207, 0.207, 0.207, ..., 0.302, 0.303, 0.303]),
#   'filename': 'raman_spectra/67641_NIST_IR.jdx'},
#  'METHANE': {'title': 'METHANE',
#   'jcamp-dx': 4.24,
#   'data type': 'INFRARED SPECTRUM',
#   'class': 'COBLENTZ',
#   'origin': 'DOW CHEMICAL COMPANY',
#   'owner': 'COBLENTZ SOCIETY',
#   'date': 1964,
#   'cas registry no': '74-82-8',
#   'molform': 'C H4',
#   'source reference': 'COBLENTZ NO. 8873',
#   '$nist source': 'COBLENTZ',
#   '$nist image': 'cob8873',
#   'spectrometer/data system': 'DOW KBr FOREPRISM',
#   'instrument parameters': 'GRATING CHANGED AT 5.0, 7.5, 15.0 MICRON',
#   'state': 'GAS (150 mmHg DILUTED TO A TOTAL PRESSURE OF 600 mmHg WITH N2)',
#   'path length': '5 CM',
#   'sampling procedure': 'TRANSMISSION',
#   'resolution': 4,
#   'data processing': 'DIGITIZED BY NIST FROM HARD COPY (FROM TWO SEGMENTS)',
#   'xunits': '1/CM',
#   'yunits': 'ABSORBANCE',
#   'xfactor': 1.0,
#   'yfactor': 1,
#   'deltax': 0.935748,
#   'firstx': 449.47,
#   'lastx': 3801.32,
#   'firsty': 0.953,
#   'maxx': 3801.32,
#   'minx': 449.47,
#   'maxy': 1.03697,
#   'miny': 0.028,
#   'npoints': 3583,
#   'xydata': '(X++(Y..Y))',
#   'end': '',
#   'x': array([ 449.47      ,  450.63968475,  451.8093695 , ..., 3799.447273  ,
#          3800.3836365 , 3801.32      ]),
#   'y': array([0.047, 0.047, 0.047, ..., 0.003, 0.003, 0.003]),
#   'filename': 'raman_spectra/74828_NIST_IR.jdx'},
#  '2-PROPANOL': {'title': '2-PROPANOL',
#   'jcamp-dx': 4.24,
#   'data type': 'INFRARED SPECTRUM',
#   'class': 'COBLENTZ',
#   'owner': 'COBLENTZ SOCIETY',
#   'date': '1963/02/20',
#   'cas registry no': '67-63-0',
#   'molform': 'C3 H8 O',
#   'source reference': 'COBLENTZ NO. 6988',
#   '$nist source': 'COBLENTZ',
#   '$nist image': 'cob6988',
#   'spectrometer/data system': 'PERKIN-ELMER 21 (GRATING)',
#   'state': 'GAS (VAPOR)',
#   'path length': '10 CM',
#   'sampling procedure': 'TRANSMISSION',
#   'resolution': 4,
#   'data processing': 'DIGITIZED BY NIST FROM HARD COPY',
#   'xunits': 'MICROMETERS',
#   'yunits': 'ABSORBANCE',
#   'xfactor': 1.0,
#   'yfactor': 1,
#   'deltax': 0.004756,
#   'firstx': 2.006,
#   'lastx': 15.009,
#   'firsty': 0.756,
#   'maxx': 15.009,
#   'minx': 2.006,
#   'maxy': 0.834,
#   'miny': 0.045,
#   'npoints': 2735,
#   'xydata': '(X++(Y..Y))',
#   'end': '',
#   'x': array([ 2.006    ,  2.0119475,  2.017895 , ..., 14.9995   , 15.00425  ,
#          15.009    ]),
#   'y': array([0.244, 0.244, 0.245, ..., 0.31 , 0.311, 0.311]),
#   'filename': 'raman_spectra/67630_NIST_IR.jdx'},
#  'FORMALDEHYDE': {'title': 'FORMALDEHYDE',
#   'jcamp-dx': 4.24,
#   'data type': 'INFRARED SPECTRUM',
#   'class': 'COBLENTZ III',
#   'origin': 'DOW CHEMICAL COMPANY',
#   'owner': 'COBLENTZ SOCIETY',
#   'date': '1978/03/16',
#   'cas registry no': '50-00-0',
#   'molform': 'C H2 O',
#   'bp': '-21 C',
#   'source reference': 'COBLENTZ NO. 10619',
#   '$nist source': 'COBLENTZ',
#   '$nist image': 'cob10619',
#   'spectrometer/data system': 'PERKIN-ELMER 297',
#   'state': 'SOLUTION (UNKNOWN CONCENTRATION IN CCl4) VS. CCl4',
#   'path length': '0.1 CM',
#   'sampling procedure': 'TRANSMISSION',
#   'resolution': 4,
#   'data processing': 'DIGITIZED BY NIST FROM HARD COPY (FROM TWO SEGMENTS)',
#   'xunits': '1/CM',
#   'yunits': 'ABSORBANCE',
#   'xfactor': 1.0,
#   'yfactor': 1,
#   'deltax': 0.924501,
#   'firstx': 590.139,
#   'lastx': 4004.32,
#   'firsty': 0.721,
#   'maxx': 4004.32,
#   'minx': 590.139,
#   'maxy': 0.899,
#   'miny': 0.019,
#   'npoints': 3694,
#   'xydata': '(X++(Y..Y))',
#   'end': '',
#   'x': array([ 590.139     ,  591.29462575,  592.4502515 , ..., 4002.470994  ,
#          4003.395497  , 4004.32      ]),
#   'y': array([0.279, 0.274, 0.272, ..., 0.118, 0.118, 0.118]),
#   'filename': 'raman_spectra/50000_NIST_IR.jdx'}}
